# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd 
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv('dataplagio.csv')
del data['Timestamp']
data.head()
# Out:
#    Que edad tienes? Cual es tu programa principal?  \
# 0                22                         Física
# 1                18                         Física
# 2                25                      I. Químca
# 3                18                       Economía
# 4                23                         Física
#
#   En querango esta tu promedio acumulado?   Que semestre estas cursando?  \
# 0                             3.75 - 3.99                             10
# 1                Estoy en primer semestre                              1
# 2                              4.5 - 4.74                              8
# 3                             3.75 - 3.99                              7
# 4                              4.0 - 4.24                             10
#
#    Que tanto crees que influye cada uno de los siguientes factores en que los estudiantes hagan fraude academico? [La necesidad de mejorar las notas]  \
# 0                                      Influye mucho
# ...

# %%
# @hidden_cell
edad=data.iloc[:,0]
programa=data.iloc[:,1]
promedio=data.iloc[:,2]
semestre=data.iloc[:,3]
razones_notas=data.iloc[:,4]
razones_demas=data.iloc[:,5]
razones_poco_interes=data.iloc[:,6]
razones_carga_academica=data.iloc[:,7]
razones_consecuencias=data.iloc[:,8]
razones_competencia=data.iloc[:,9]
razones_supervision=data.iloc[:,10]
norazones_honestidad=data.iloc[:,11]
norazones_companeros=data.iloc[:,12]
norazones_descubiertos=data.iloc[:,13]
norazones_confianza_profesores=data.iloc[:,14]
norazones_sanciones=data.iloc[:,15]
norazones_aprender=data.iloc[:,16]
actitudes_propias_estudiar=data.iloc[:,17]
actitudes_propias_tiempo=data.iloc[:,18]
actitudes_propias_creditos=data.iloc[:,19]
actitudes_propias_notas=data.iloc[:,20]
actitudes_propias_conciencia=data.iloc[:,21]
actitudes_propias_engano=data.iloc[:,22]
actitudes_profesores_vigilar=data.iloc[:,23]
actitudes_profesores_ensenanza=data.iloc[:,24]
actitudes_profesores_evaluaciones=data.iloc[:,25]
actitudes_profesores_memoria=data.iloc[:,26]
actitudes_profesores_panico=data.iloc[:,27]
actitudes_otros_competitivos=data.iloc[:,28]
actitudes_otros_rechazo=data.iloc[:,29]
actitudes_otros_denuncia=data.iloc[:,30]
actitudes_otros_grupo=data.iloc[:,31]
actitudes_otros_reflexion=data.iloc[:,32]

# %% [markdown]
# #Empezemos con unas estadisticas descriptivas de los datos

# %%
fig=plt.figure(figsize=(20,5))
fig.suptitle('Informacion de los encuestados', fontsize=18)
plt.subplots_adjust(hspace=0.8)
plt.subplot(221)
edad.value_counts().plot(kind='bar', title='Edades')
plt.subplot(222)
semestre.value_counts().plot(kind='bar', title='Semestre')
plt.subplot(223)
promedio.value_counts().plot(kind='bar', title='Promedio Acumulado')
plt.subplot(224)
programa.value_counts().plot(kind='bar', title='Programa')
plt.title('Estadisticas descriptivas de informacion social')

# %%
fig=plt.figure(figsize=(20,20))
fig.suptitle('Que tanto crees que influye cada uno de los siguientes factores en que los estudiantes hagan fraude academico?', fontsize=18)
plt.subplot(421)
razones_notas.value_counts().plot(kind='pie', title='La necesidad de mejorar las notas', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(422)
razones_demas.value_counts().plot(kind='pie', title='El hecho de que los demas lo hagan', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(423)
razones_poco_interes.value_counts().plot(kind='pie', title='El poco interes en la materia', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(424)
razones_carga_academica.value_counts().plot(kind='pie', title='La excesiva carga academica', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(425)
razones_consecuencias.value_counts().plot(kind='pie', title='El no medir consecuencias', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(426)
razones_competencia.value_counts().plot(kind='pie', title='La competencia en la universidad', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(427)
razones_supervision.value_counts().plot(kind='pie', title='No hay suficiente supervision', autopct='%1.1f%%')
plt.ylabel('')

# %%
fig=plt.figure(figsize=(20,20))
fig.suptitle('Que tanto crees que influye cada uno de los siguientes factores en que los estudiantes NO hagan fraude academico?', fontsize=18)
plt.subplot(321)
norazones_honestidad.value_counts().plot(kind='pie', title='Tener un alto sentido de honestidad', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(322)
norazones_companeros.value_counts().plot(kind='pie', title='Saber que es injusto con mis companeros', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(323)
norazones_descubiertos.value_counts().plot(kind='pie', title='Sentir verguenza de ser descubierto', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(324)
norazones_confianza_profesores.value_counts().plot(kind='pie', title='Sentir que estoy traicionando la verguenza del profesor', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(325)
norazones_sanciones.value_counts().plot(kind='pie', title='Las posibles sanciones son muy fuertes', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(326)
norazones_aprender.value_counts().plot(kind='pie', title='Querer aprender', autopct='%1.1f%%')
plt.ylabel('')

# %%
fig=plt.figure(figsize=(20,20))
fig.suptitle('Que tan influyentes crees que serian las siguiente actitudes de tus profesores para evitar que hicieras fraude?', fontsize=18)
plt.subplot(321)
actitudes_propias_estudiar.value_counts().plot(kind='pie', title='Estudiar mejor para los examenes', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(322)
actitudes_propias_tiempo.value_counts().plot(kind='pie', title='Manejar mejor mi tiempo', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(323)
actitudes_propias_creditos.value_counts().plot(kind='pie', title='Disminuir el numero de creditos por semestre', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(324)
actitudes_propias_notas.value_counts().plot(kind='pie', title='Darle menos importancia a las notas', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(325)
actitudes_propias_conciencia.value_counts().plot(kind='pie', title='Tomar conciencia de que es un acto grave', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(326)
actitudes_propias_engano.value_counts().plot(kind='pie', title='Entender que cuando hago plagio me engano', autopct='%1.1f%%')
plt.ylabel('')

# %%
fig=plt.figure(figsize=(20,20))
fig.suptitle('Que tan influyentes crees que serian las siguiente actitudes de tus profesores para evitar que hicieras fraude?', fontsize=18)
plt.subplot(321)
actitudes_profesores_vigilar.value_counts().plot(kind='pie', title='Vigilar mejor los examenes', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(322)
actitudes_profesores_ensenanza.value_counts().plot(kind='pie', title='Mejorar su metodo de ensenanza', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(323)
actitudes_profesores_evaluaciones.value_counts().plot(kind='pie', title='Hacer evaluaciones mas consistentes con lo ensenado', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(324)
actitudes_profesores_memoria.value_counts().plot(kind='pie', title='No hacer examenes de seleccion multiple o de memoria', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(325)
actitudes_profesores_panico.value_counts().plot(kind='pie', title='Generar panico e imponer sanciones fuertes', autopct='%1.1f%%')
plt.ylabel('')

# %%
fig=plt.figure(figsize=(20,20))
fig.suptitle('Que tan influyentes crees que serian las siguientes actitudes de tus companeros para evitar que hicieras fraude?', fontsize=18)
plt.subplot(321)
actitudes_otros_competitivos.value_counts().plot(kind='pie', title='Que fueran menos competitivos', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(322)
actitudes_otros_rechazo.value_counts().plot(kind='pie', title='Mostrar rechazo a los que hacen plagio', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(323)
actitudes_otros_denuncia.value_counts().plot(kind='pie', title='Denunciar los casos de fraude', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(324)
actitudes_otros_grupo.value_counts().plot(kind='pie', title='Fomentar el companerismo y el estudio en grupo', autopct='%1.1f%%')
plt.ylabel('')
plt.subplot(325)
actitudes_otros_reflexion.value_counts().plot(kind='pie', title='Generar una reflexion moral en los que hacen plagio', autopct='%1.1f%%')
plt.ylabel('')

# %% [markdown]
# ##Aca un resumen de las estadisticas:
# - Las caracteristicas mas comunes dentro de nuestros encuestados son:
#     * Estudiantes con 22 anos
#     * Estudiantes de 8 semestre (en general de semestres avanzados)
#     * Promedio acumulado entre 3.75 y 3.99
#     * Estudiantes de Fisica
# - En su orden, los factores mas influyentes en que los estudiantes cometan plagio son los siguientes:
#     1. La necesidad de mejorar las notas.
#     2. No medir las consecuencias en el momento.
#     2. La excesiva carga academica.
#     3. La falta de interes en la materia.
#     4. La competencia que existe en la universidad.
#     5. El hecho de que los demas lo hagan.
#     6. La falta de supervision durante los examenes.
# - En su orden, los factores mas influyentes en que los estudiantes NO cometan plagio son los siguientes:
#     1. Tener un alto sentido de honestidad.
#     2. Que las posibles sanciones sean muy fuertes.
#     3. Querer aprender.
#     4. Sentir verguenza de ser descubierto.
#     5. Sentir que traicionan la confianza de los profesores.
#     6. Saber que es injusto con sus companeros.
# - En su orden, las actitudes de los estudiantes mas influyentes para evitar que hicieran fraude son las siguientes:
#     1. Manejar mejor su tiempo.
#     2. Estudiar mejor para los examenes.
#     3. Tomar conciencia de que es un acto grave.
#     4. Entender que cuando hago plagio me engano a mi mismo.
#     5. Darle menos importancia a las notas.
#     6. Disminuir el numero de creditos por semestre.
# - En su orden, las actitudes de profesores mas influyentes para evitar que los estudiantes hicieran fraude son las siguientes:
#     1. Hacer evaluaciones mas consistentes con lo ensenado.
#     2. Mejorar su metodo de ensenanza.
#     3. No hacer examenes de seleccion multiple o de memoria.
#     4. Generar panico e imponer sanciones fuertes.
#     5. Vigilar mejor los examenes.
# - En su orden, las actitudes de los companeros mas influyentes para evitar que los estudiantes hicieran fraude son las siguientes:
#     1. Denunciar los casos de fraude.
#     2. Mostrar rechazo a los que hacen fraude.
#     3. Fomentar el companerismo y el estudio en grupo.
#     4. Generar una reflexion moral en los que hacen fraude.
#     5. Ser menos competitivos.

# %% [markdown]
# # Ahora, haremos buscaremos si existe algun tipo de agrupamiento en los datos usando k-means

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from sklearn.utils.fixes import signature
from sklearn.svm import SVC
from collections import OrderedDict

# %%
dicc_clases = OrderedDict()
new_data=data.copy()
index=new_data.columns
for i in range(len(new_data.columns)):
        le = LabelEncoder()
        le.fit(new_data[index[i]].astype(str))
        clases=le.classes_
        dicc_clases.update({index[i]:clases})
        new_data[index[i]] = le.fit_transform(new_data[index[i]].astype(str))

# %% [markdown]
# Buscamos optimizar el numero de ks usando el metodo del codo.

# %%
distancias=[]
for i in range(1,10):
    km=KMeans(n_clusters=i)
    km.fit(new_data)
    distancias.append(km.inertia_)

n_cluster=np.linspace(1,len(distancias),len(distancias))
plt.plot(n_cluster,distancias)
plt.scatter(n_cluster,distancias)
plt.xlabel('Num. Clusters')
plt.ylabel('Suma de distancias cuadradas')

# %% [markdown]
# Nos quedamos con un numero de clusters de 3. Ahora, lo que buscaremos es entender el agrupamiento de estos datos. Para ello, buscaremos las preguntas que generaron los distintos agrupamientos, es decir, aquellas en las que hubo discrepancias entre los encuestados. Esto puede permitir entender las diferentes posturas que existen en la universidad con respecto al plagio y generar politicas con objetivos diferentes para cada poblacion.

# %%
kmeans = KMeans(n_clusters=3).fit(new_data)
labels=kmeans.labels_
centroids=kmeans.cluster_centers_
centroids=np.round(centroids)
fil,col=centroids.shape

list_clases=list(dicc_clases.values())
list_nombres=[]
for f in range(fil):
    list_lab=[]
    for c in range(col):
        list_lab.append(list_clases[c][int(centroids[f,c])])
    list_nombres.append(list_lab)
print('Cluster 1:')
print([x for x in list_nombres[0] if x != 'nan'])
print('Cluster 2:')
print([x for x in list_nombres[1] if x != 'nan'])
print('Cluster 3:')
print([x for x in list_nombres[2] if x != 'nan'])
print(dicc_clases.keys())
# Out:
# Cluster 1:
# ['20', 'I. Químca', '4.0 - 4.24', '4', 'Influye totalmente', 'Influye totalmente', 'Influye totalmente', 'Influye totalmente', 'Influye totalmente', 'Influye un poco', 'Influye un poco', 'Influye totalmente', 'Influye un poco', 'Influye totalmente', 'Influye un poco', 'Influye totalmente', 'Influye totalmente', 'Influye totalmente', 'Influye totalmente', 'Influye un poco', 'Influye totalmente', 'Influye totalmente', 'Influye un poco', 'Influye totalmente', 'Influye totalmente', 'Influye totalmente', 'Influye un poco', 'Influye totalmente', 'Influye un poco', 'Influye totalmente', 'Influye totalmente', 'Influye un poco', 'Influye un poco']
# Cluster 2:
# ...

# %% [markdown]
# Imprimimos los 3 clusters y los 'ejes', es decir, las preguntas. Miramos por aparte en un excel en donde se muestran las discrepancias (es mas facil visualmente). Y encontramos que:
# - En los factores que influyen para que hagan plagio hay diferencias en:
#     * La competencia por las notas que se promueve en la universidad
#     * Saber que es injusto con mis companeros
# - En los factores que influyen en que NO hagan plagio hay diferencias en:
#     * Sentir que estoy traicionando la confianza del profesor
# - En las actitudes o comportamientos propios de los estudiantes para evitar hacer plagio hay diferencias en:
#     * Disminuir el numero de creditos que toman por semestre
#     * Entender que cuando hago plagio me engano a mi mismo
# - En las actitudes o comportamientos de los profesores para evitar que los estudiantes hagan plagio hay diferencias en:
#     * No hacer examenes de memoria o de seleccion multiple
#     * Generar panico y sanciones fuertes
# - En las actitudes o comportamientos de los companeros para evitar que los estudiantes hagan plagio hay diferencias en
#     * Ser menos competitivos
#     * Fomentar el companerismo y el estudio en grupo

# %% [markdown]
# Asimismo, parece que hubiera distintas percepciones entre: estudiantes comenzando su carrera, estudiantes mas avanzados y estudiantes a punto de terminar. Consideramos que las diferencias se presentan principalmente entre cada programa, sin embargo, los resultados de este eje en los clusters no son como se esperaban y creemos que para sacar conclusiones sobre la influencia del programa necesitariamos tener mayor cantidad de datos.

# %% [markdown]
# #Estudiantes de Fisica
# Dentro de las encuestas obtuvimos una alta tasa de respuesta de estudiantes de fisica, esto principalmente porque eran los mas cercanos a nosotros. Vamos a usar esta informacion para entender si existen unos mecanismos especificos que se puedan usar en nuestro departamento para evitar el fraude academico. Para esto, buscaremos predecir la carrera de los estudiantes y veremos la influencia que tiene cada una de las preguntas en determinar si el estudiante es de fisica o no. Fisica es el label 7.

# %%
other_data=new_data.copy()
labeled=np.where(other_data["Cual es tu programa principal?"]==7,1,0)
other_data["Cual es tu programa principal?"]=labeled

# %%
y_train=other_data["Cual es tu programa principal?"]
x_train=other_data.iloc[:,4:] #Nos interesan solo las preguntas.

# %%
import sklearn
from sklearn.svm import SVC
from sklearn.feature_selection import RFECV

estimator = SVC(kernel="linear")
selector = RFECV(estimator, cv=10,scoring='accuracy')
selector.fit(x_train, y_train)
print('Numero optimo de variables: %d'
 % selector.n_features_)
print(other_data.columns.values[selector.support_])
# Out:
# Numero optimo de variables: 4
# [ 'Que tanto crees que influye cada uno de los siguientes factores en que los estudiantes hagan fraude academico? [El no medir las consecuencias en el momento]'
#  'Que tan influyentes crees que seran las siguientes actitudes o comportamientos tuyos para evitar que hicieras fraude? [Tomar conciencia de que el fraude es un acto grave]'
#  'Que tan influyentes crees que seran las siguientes actitudes o comportamientos tuyos para evitar que hicieras fraude? [Entender que cuando hago plagio me engano a mi� mismo]'
#  'Que tan influyentes crees que seran las siguientes actitudes o comportamientos de tus profesores para evitar que hicieras fraude? [Generar panico e imponer sanciones fuertes]']
# /home/juan/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:10: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 33 but corresponding boolean dimension is 29

# %% [markdown]
# El metodo anterior se denomina 'recursive feature elimination and cross-validated selection' y lo que busca es encontrar las variables que son mas representativas para predecir que un estudiante es de fisica con un Support Vector Classifier. De acuerdo con esto, vemos que son estas 4 preguntas las mas relevantes dentro de los estudiantes de fisica. Creemos que en general los estudiantes consideran que la mejor forma de evitar el plagio es un cuestionamiento moral propio, acompanado de unas sanciones fuertes impuestas por los profesores y la universidad que prevengan estos actos. Cabe destacar tambien que en el departamento parece ser que el fraude es un acto circunstancial y no premeditado, el cual se comete por no preveer las consecuencias en el momento justo de realizarse.
#
# Cabe destacar tambien que al parecer la actitud de los companeros no es del todo relevante para evitar el plagio en Fisica.

# %%
#Seleccionamos los mejores predictores usando LinearRegression
from sklearn.linear_model import LinearRegression
estimator2 = LinearRegression()
selector2 = RFECV(estimator2, cv=10)
selector2.fit(x_train, y_train)
print('Numero optimo de variables: %d'
 % selector2.n_features_)
print(other_data.columns.values[selector2.support_])
# Out:
# Numero optimo de variables: 1
# [ 'Que tanto crees que influye cada uno de los siguientes factores en que los estudiantes hagan fraude academico? [El no medir las consecuencias en el momento]']
# /home/juan/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:8: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 33 but corresponding boolean dimension is 29

# %% [markdown]
# La regresion logistica es consistente con el analisis del fraude como un acto circunstancial.

# %% [markdown]
# Queda por analizar el score de estos features para predecir si los estudiantes son de fisica o no. Sin embargo, consideramos que no es adecuado realizar este proceso porque la cantidad de datos, lamentablemente, no es suficiente.
